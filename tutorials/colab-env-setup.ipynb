# %% [markdown]
# # Brainiak Tutorials Environment Setup (Local .venv)

# %% [markdown]
# ## Packages are already installed in .venv — nothing to do here.

# %% [markdown]
# ## Repo is already cloned — nothing to do here.

# %% [markdown]
# ## Download datasets for tutorials
# Pick one of the following datasets to download for the appropriate tutorial you will work on.

# %%
import os
import gdown

# Datasets go into brainiak_datasets/ at the project root (one level up from tutorials/)
datasets_dir = os.path.normpath(os.path.join(os.getcwd(), '..', 'brainiak_datasets'))
os.makedirs(datasets_dir, exist_ok=True)
print(f'Dataset directory: {datasets_dir}')
# Out:
# Dataset directory: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets

# %% [markdown]
# ### Download VDC dataset - (tutorial notebooks 02-05)
# Dataset size: 5.3 GB

# %%
gdown.download(id='1tiEjtp96zwIdnl3p726llj5KMETnNJ4A', output=f'{datasets_dir}/02-data-handling-simulated-dataset.zip')
# !unzip -q {datasets_dir}/02-data-handling-simulated-dataset.zip -d {datasets_dir}/

gdown.download(id='1PrnucQ4hXqUY8gl6ysGJJiTreYu7KOLz', output=f'{datasets_dir}/vdc.zip')
# !unzip -q {datasets_dir}/vdc.zip -d {datasets_dir}/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tiEjtp96zwIdnl3p726llj5KMETnNJ4A
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/02-data-handling-simulated-dataset.zip
# 100%|██████████| 7.64k/7.64k [00:00<00:00, 12.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1PrnucQ4hXqUY8gl6ysGJJiTreYu7KOLz
# From (redirected): https://drive.google.com/uc?id=1PrnucQ4hXqUY8gl6ysGJJiTreYu7KOLz&confirm=t&uuid=6e7f03ab-0dd9-495e-bdb8-21e1c6e10f6b
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/vdc.zip
# 100%|██████████| 5.69G/5.69G [08:21<00:00, 11.3MB/s]

# %% [markdown]
# ### Download NinetySix dataset - (tutorial notebook 06-rsa)
# Dataset size: 150 MB

# %%
gdown.download(id='14m-YY-N3mCjCdHGkeVlTS4uA7WJzbQS0', output=f'{datasets_dir}/NinetySix.zip')
# !unzip -q {datasets_dir}/NinetySix.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=14m-YY-N3mCjCdHGkeVlTS4uA7WJzbQS0
# From (redirected): https://drive.google.com/uc?id=14m-YY-N3mCjCdHGkeVlTS4uA7WJzbQS0&confirm=t&uuid=35c32419-fcf4-4a1a-8e1f-8e7b83799f67
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/NinetySix.zip
# 100%|██████████| 154M/154M [00:30<00:00, 4.98MB/s]

# %% [markdown]
# ### Download Face-scene dataset - (tutorial notebooks 07-searchlight, 09-fcma)
# Dataset size: 255 MB

# %%
gdown.download(id='1LBhKWx5NSlndUlBev3jP997wNiM6HA9N', output=f'{datasets_dir}/face_scene.zip')
# !unzip -q {datasets_dir}/face_scene.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1LBhKWx5NSlndUlBev3jP997wNiM6HA9N
# From (redirected): https://drive.google.com/uc?id=1LBhKWx5NSlndUlBev3jP997wNiM6HA9N&confirm=t&uuid=1e8d7689-c189-43cd-aaac-45573f4f03b2
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/face_scene.zip
# 100%|██████████| 268M/268M [00:25<00:00, 10.7MB/s]

# %% [markdown]
# ### Download Latatt dataset - (tutorial notebook 08-connectivity)
# Dataset size: 584 MB

# %%
gdown.download(id='1iX5nLZvQsWuM5AmKeiBNoP8QkZjlOY7T', output=f'{datasets_dir}/latatt.zip')
# !unzip -q {datasets_dir}/latatt.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1iX5nLZvQsWuM5AmKeiBNoP8QkZjlOY7T
# From (redirected): https://drive.google.com/uc?id=1iX5nLZvQsWuM5AmKeiBNoP8QkZjlOY7T&confirm=t&uuid=5ee976b0-5044-4ceb-963e-9059f0ffd9d5
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/latatt.zip
# 100%|██████████| 613M/613M [00:58<00:00, 10.5MB/s]

# %% [markdown]
# ### Download Pieman2 dataset - (tutorial notebooks 10-isc, 11-srm)
# Dataset size: 2.65 GB

# %%
gdown.download(id='1IBA39ZZjeGS1u_DvZdiw1AZZQMS3K5q0', output=f'{datasets_dir}/Pieman2.zip')
# !unzip -q {datasets_dir}/Pieman2.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1IBA39ZZjeGS1u_DvZdiw1AZZQMS3K5q0
# From (redirected): https://drive.google.com/uc?id=1IBA39ZZjeGS1u_DvZdiw1AZZQMS3K5q0&confirm=t&uuid=193f4b72-8bea-4469-84b1-dddd14c2a48a
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/Pieman2.zip
# 100%|██████████| 2.85G/2.85G [03:53<00:00, 12.2MB/s]

# %% [markdown]
# ### Download Raider dataset - (tutorial notebook 11-srm)
# Dataset size: 31 MB

# %%
gdown.download(id='1zCQoulK_rlzzRb4n6YMVp2cI8vZpxnwx', output=f'{datasets_dir}/raider.zip')
# !unzip -q {datasets_dir}/raider.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1zCQoulK_rlzzRb4n6YMVp2cI8vZpxnwx
# From (redirected): https://drive.google.com/uc?id=1zCQoulK_rlzzRb4n6YMVp2cI8vZpxnwx&confirm=t&uuid=924f13bf-3c14-4228-8809-7f900ed576c9
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/raider.zip
# 100%|██████████| 32.7M/32.7M [00:02<00:00, 13.4MB/s]

# %% [markdown]
# ### Download Sherlock_processed dataset - (tutorial notebook 12-hmm)
# Dataset size: 255 MB

# %%
gdown.download(id='11y9iQUoNVyVLANllKebFUrqdvQt-vsXm', output=f'{datasets_dir}/Sherlock_processed.zip')
# !unzip -q {datasets_dir}/Sherlock_processed.zip -d {datasets_dir}/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11y9iQUoNVyVLANllKebFUrqdvQt-vsXm
# From (redirected): https://drive.google.com/uc?id=11y9iQUoNVyVLANllKebFUrqdvQt-vsXm&confirm=t&uuid=2736e71c-8ecb-4255-9136-38de5451794c
# To: /Users/atulkrishnan/Desktop/brainiak-tutorials/brainiak_datasets/Sherlock_processed.zip
# 100%|██████████| 268M/268M [00:14<00:00, 18.1MB/s]

# %% [markdown]
# ### Remove downloaded zip files (uncomment to run)

# %%
# !rm {datasets_dir}/*.zip

# %%
#!cd /root; wget -q --show-progress --no-check-certificate -r 'https://docs.google.com/uc?export=download&id=1ZglrmkYw8isBAfsL53n9JgHEucmrnm4E' -O 'tutorials.zip'
#!cd /root; unzip tutorials.zip

# %%
#!cd /root/brainiak_datasets; rm *.zip
